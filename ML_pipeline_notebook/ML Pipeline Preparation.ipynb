# %% [markdown]
# # ML Pipeline Preparation
# ### 1. Import libraries and load data from database

# %%
# import libraries
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import re
import pickle

# nltk
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

#sklearn
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report
# Out:
# [nltk_data] Downloading package punkt to /Users/zora/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# load data from database
engine = create_engine('sqlite:///../webapp/data/DisasterResponse.db')
df = pd.read_sql_table('messages_categories', engine)

# create X and y dataframes for pipeline
X = df['message'] # predictors
y = df.drop(['id', 'message', 'original', 'genre'], axis = 1).astype('int64') # labels

# %% [markdown]
# ### 2. Write a tokenization function to process text data

# %%
def tokenize(text):
    text_norm = re.sub(r'[^a-zA-Z0-9]', ' ', text) # normalize: remove punctuation
    word_list = word_tokenize(text_norm) # tokenize 
    word_list_clean = [w for w in word_list if w not in stopwords.words('english')] # remove stopwords
    word_list_stemmed = [PorterStemmer().stem(w) for w in word_list_clean] # stemm words
    return word_list_stemmed

# %% [markdown]
# ### 3. Build a machine learning pipeline

# %%
# build a pipeline with countvectorizer, tfidf and random forest classifier
pipeline_RF = Pipeline([
    ('vect', CountVectorizer(tokenizer = tokenize)),
    ('tfidf', TfidfTransformer()),
    ('multi-clf', MultiOutputClassifier(RandomForestClassifier()))
])

# %% [markdown]
# ### 4. Train pipeline

# %%
# split dataset into train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# fit data
pipeline_RF.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x11c057ca0>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('multi-clf',
#                  MultiOutputClassifier(estimator=RandomForestClassifier()))])

# %% [markdown]
# ### 5. Test model

# %%
# run prediction with test data
y_pred = pipeline_RF.predict(X_test)

# %%
# print precision, recall and f1-score
i = 0
for col in y_test:
    print('Evaluation for "{}": \n {} \n\n'.format(col, classification_report(y_test[col], y_pred[:,i])))
    i += 1
# Out:
# Evaluation for "related":
#                precision    recall  f1-score   support
#
#            0       0.70      0.42      0.53      1862
#            1       0.84      0.94      0.89      5946
#            2       0.27      0.30      0.28        57
#
#     accuracy                           0.81      7865
#    macro avg       0.60      0.55      0.56      7865
# weighted avg       0.80      0.81      0.80      7865
#
#
#
# Evaluation for "request":
#                precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      6555
#            1       0.83      0.49      0.62      1310
#
#     accuracy                           0.90      7865
#    macro avg       0.87      0.74      0.78      7865
# weighted avg       0.89      0.90      0.89      7865
#
#
#
# Evaluation for "offer":
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7838
#            1       0.00      0.00      0.00        27
#
#     accuracy                           1.00      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      1.00      0.99      7865
#
#
#
# Evaluation for "aid_related":
#                precision    recall  f1-score   support
#
#            0       0.80      0.85      0.82      4650
#            1       0.76      0.70      0.73      3215
#
#     accuracy                           0.79      7865
#    macro avg       0.78      0.77      0.78      7865
# weighted avg       0.78      0.79      0.78      7865
#
#
#
# Evaluation for "medical_help":
#                precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      7273
#            1       0.64      0.09      0.16       592
#
#     accuracy                           0.93      7865
#    macro avg       0.78      0.55      0.56      7865
# weighted avg       0.91      0.93      0.90      7865
#
#
#
# Evaluation for "medical_products":
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7502
#            1       0.85      0.08      0.15       363
#
#     accuracy                           0.96      7865
#    macro avg       0.91      0.54      0.56      7865
# weighted avg       0.95      0.96      0.94      7865
#
#
#
# Evaluation for "search_and_rescue":
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      7646
#            1       0.76      0.07      0.13       219
#
#     accuracy                           0.97      7865
#    macro avg       0.87      0.54      0.56      7865
# weighted avg       0.97      0.97      0.96      7865
#
#
#
# Evaluation for "security":
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7725
#            1       0.00      0.00      0.00       140
#
#     accuracy                           0.98      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.96      0.98      0.97      7865
#
#
#
# Evaluation for "military":
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      7621
#            1       0.58      0.05      0.08       244
#
#     accuracy                           0.97      7865
#    macro avg       0.77      0.52      0.53      7865
# weighted avg       0.96      0.97      0.96      7865
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Evaluation for "child_alone":
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7865
#
#     accuracy                           1.00      7865
#    macro avg       1.00      1.00      1.00      7865
# weighted avg       1.00      1.00      1.00      7865
#
#
#
# Evaluation for "water":
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7406
#            1       0.84      0.35      0.49       459
#
#     accuracy                           0.96      7865
#    macro avg       0.90      0.67      0.73      7865
# weighted avg       0.95      0.96      0.95      7865
#
#
#
# Evaluation for "food":
#                precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      7003
#            1       0.87      0.61      0.72       862
#
#     accuracy                           0.95      7865
#    macro avg       0.91      0.80      0.84      7865
# weighted avg       0.94      0.95      0.94      7865
#
#
#
# Evaluation for "shelter":
#                precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      7212
#            1       0.83      0.39      0.53       653
#
#     accuracy                           0.94      7865
#    macro avg       0.89      0.69      0.75      7865
# weighted avg       0.94      0.94      0.93      7865
#
#
#
# Evaluation for "clothing":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7757
#            1       0.95      0.18      0.30       108
#
#     accuracy                           0.99      7865
#    macro avg       0.97      0.59      0.65      7865
# weighted avg       0.99      0.99      0.98      7865
#
#
#
# Evaluation for "money":
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7692
#            1       0.67      0.02      0.04       173
#
#     accuracy                           0.98      7865
#    macro avg       0.82      0.51      0.52      7865
# weighted avg       0.97      0.98      0.97      7865
#
#
#
# Evaluation for "missing_people":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7785
#            1       0.00      0.00      0.00        80
#
#     accuracy                           0.99      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.98      0.99      0.98      7865
#
#
#
# Evaluation for "refugees":
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      7599
#            1       0.55      0.02      0.04       266
#
#     accuracy                           0.97      7865
#    macro avg       0.76      0.51      0.51      7865
# weighted avg       0.95      0.97      0.95      7865
#
#
#
# Evaluation for "death":
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7522
#            1       0.86      0.13      0.22       343
#
#     accuracy                           0.96      7865
#    macro avg       0.91      0.56      0.60      7865
# weighted avg       0.96      0.96      0.95      7865
#
#
#
# Evaluation for "other_aid":
#                precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      6837
#            1       0.67      0.03      0.06      1028
#
#     accuracy                           0.87      7865
#    macro avg       0.77      0.51      0.50      7865
# weighted avg       0.85      0.87      0.82      7865
#
#
#
# Evaluation for "infrastructure_related":
#                precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      7376
#            1       0.00      0.00      0.00       489
#
#     accuracy                           0.94      7865
#    macro avg       0.47      0.50      0.48      7865
# weighted avg       0.88      0.94      0.91      7865
#
#
#
# Evaluation for "transport":
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7489
#            1       0.69      0.10      0.18       376
#
#     accuracy                           0.95      7865
#    macro avg       0.82      0.55      0.58      7865
# weighted avg       0.94      0.95      0.94      7865
#
#
#
# Evaluation for "buildings":
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7484
#            1       0.72      0.13      0.22       381
#
#     accuracy                           0.96      7865
#    macro avg       0.84      0.56      0.60      7865
# weighted avg       0.95      0.96      0.94      7865
#
#
#
# Evaluation for "electricity":
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7713
#            1       0.78      0.05      0.09       152
#
#     accuracy                           0.98      7865
#    macro avg       0.88      0.52      0.54      7865
# weighted avg       0.98      0.98      0.97      7865
#
#
#
# Evaluation for "tools":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7822
#            1       0.00      0.00      0.00        43
#
#     accuracy                           0.99      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      0.99      0.99      7865
#
#
#
# Evaluation for "hospitals":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7771
#            1       0.00      0.00      0.00        94
#
#     accuracy                           0.99      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.98      0.99      0.98      7865
#
#
#
# Evaluation for "shops":
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7827
#            1       0.00      0.00      0.00        38
#
#     accuracy                           1.00      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      1.00      0.99      7865
#
#
#
# Evaluation for "aid_centers":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7783
#            1       0.00      0.00      0.00        82
#
#     accuracy                           0.99      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.98      0.99      0.98      7865
#
#
#
# Evaluation for "other_infrastructure":
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7549
#            1       0.00      0.00      0.00       316
#
#     accuracy                           0.96      7865
#    macro avg       0.48      0.50      0.49      7865
# weighted avg       0.92      0.96      0.94      7865
#
#
#
# Evaluation for "weather_related":
#                precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92      5695
#            1       0.84      0.71      0.77      2170
#
#     accuracy                           0.88      7865
#    macro avg       0.87      0.83      0.85      7865
# weighted avg       0.88      0.88      0.88      7865
#
#
#
# Evaluation for "floods":
#                precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      7246
#            1       0.88      0.50      0.64       619
#
#     accuracy                           0.95      7865
#    macro avg       0.92      0.75      0.81      7865
# weighted avg       0.95      0.95      0.95      7865
#
#
#
# Evaluation for "storm":
#                precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      7139
#            1       0.74      0.54      0.62       726
#
#     accuracy                           0.94      7865
#    macro avg       0.85      0.76      0.79      7865
# weighted avg       0.93      0.94      0.94      7865
#
#
#
# Evaluation for "fire":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7768
#            1       1.00      0.01      0.02        97
#
#     accuracy                           0.99      7865
#    macro avg       0.99      0.51      0.51      7865
# weighted avg       0.99      0.99      0.98      7865
#
#
#
# Evaluation for "earthquake":
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      7129
#            1       0.90      0.77      0.83       736
#
#     accuracy                           0.97      7865
#    macro avg       0.94      0.88      0.91      7865
# weighted avg       0.97      0.97      0.97      7865
#
#
#
# Evaluation for "cold":
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7707
#            1       0.71      0.09      0.17       158
#
#     accuracy                           0.98      7865
#    macro avg       0.85      0.55      0.58      7865
# weighted avg       0.98      0.98      0.97      7865
#
#
#
# Evaluation for "other_weather":
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7448
#            1       0.62      0.04      0.07       417
#
#     accuracy                           0.95      7865
#    macro avg       0.78      0.52      0.52      7865
# weighted avg       0.93      0.95      0.93      7865
# Evaluation for "direct_report":
#                precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92      6349
#            1       0.82      0.37      0.51      1516
#
#     accuracy                           0.86      7865
#    macro avg       0.84      0.67      0.71      7865
# weighted avg       0.86      0.86      0.84      7865

# %% [markdown]
# ### 6. Improve model

# %%
# define parameters for gridsearch
parameters_RF = {
    'vect__max_df': (.6, 1),
    'tfidf__norm': ('l1', 'l2'),
    'multi-clf__estimator__criterion': ('gini', 'entropy')
}

# build parameter grid and fit data
cv_RF = GridSearchCV(pipeline_RF, parameters_RF)
cv_RF.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('vect',
#                                         CountVectorizer(tokenizer=<function tokenize at 0x11c057ca0>)),
#                                        ('tfidf', TfidfTransformer()),
#                                        ('multi-clf',
#                                         MultiOutputClassifier(estimator=RandomForestClassifier()))]),
#              param_grid={'multi-clf__estimator__criterion': ('gini', 'entropy'),
#                          'tfidf__norm': ('l1', 'l2'),
#                          'vect__max_df': (0.6, 1)})

# %% [markdown]
# ### 7. Test tuned model

# %%
# run prediction with test data
y_pred = cv_RF.predict(X_test)

# print precision, recall and f1-score
i = 0
for col in y_test:
    print('Evaluation for "{}": \n {} \n\n'.format(col, classification_report(y_test[col], y_pred[:,i])))
    i += 1
# Out:
# Evaluation for "related":
#                precision    recall  f1-score   support
#
#            0       0.68      0.42      0.52      1862
#            1       0.84      0.94      0.88      5946
#            2       0.26      0.30      0.28        57
#
#     accuracy                           0.81      7865
#    macro avg       0.59      0.55      0.56      7865
# weighted avg       0.80      0.81      0.79      7865
#
#
#
# Evaluation for "request":
#                precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      6555
#            1       0.83      0.50      0.62      1310
#
#     accuracy                           0.90      7865
#    macro avg       0.87      0.74      0.78      7865
# weighted avg       0.89      0.90      0.89      7865
#
#
#
# Evaluation for "offer":
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7838
#            1       0.00      0.00      0.00        27
#
#     accuracy                           1.00      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      1.00      0.99      7865
#
#
#
# Evaluation for "aid_related":
#                precision    recall  f1-score   support
#
#            0       0.80      0.85      0.82      4650
#            1       0.76      0.69      0.72      3215
#
#     accuracy                           0.78      7865
#    macro avg       0.78      0.77      0.77      7865
# weighted avg       0.78      0.78      0.78      7865
#
#
#
# Evaluation for "medical_help":
#                precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96      7273
#            1       0.56      0.08      0.15       592
#
#     accuracy                           0.93      7865
#    macro avg       0.75      0.54      0.55      7865
# weighted avg       0.90      0.93      0.90      7865
#
#
#
# Evaluation for "medical_products":
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7502
#            1       0.85      0.08      0.15       363
#
#     accuracy                           0.96      7865
#    macro avg       0.91      0.54      0.56      7865
# weighted avg       0.95      0.96      0.94      7865
#
#
#
# Evaluation for "search_and_rescue":
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      7646
#            1       0.70      0.07      0.13       219
#
#     accuracy                           0.97      7865
#    macro avg       0.83      0.54      0.56      7865
# weighted avg       0.97      0.97      0.96      7865
#
#
#
# Evaluation for "security":
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7725
#            1       0.00      0.00      0.00       140
#
#     accuracy                           0.98      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.96      0.98      0.97      7865
#
#
#
# Evaluation for "military":
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      7621
#            1       0.65      0.06      0.11       244
#
#     accuracy                           0.97      7865
#    macro avg       0.81      0.53      0.55      7865
# weighted avg       0.96      0.97      0.96      7865
#
#
#
# Evaluation for "child_alone":
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7865
#
#     accuracy                           1.00      7865
#    macro avg       1.00      1.00      1.00      7865
# weighted avg       1.00      1.00      1.00      7865
#
#
#
# Evaluation for "water":
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7406
#            1       0.87      0.41      0.55       459
#
#     accuracy                           0.96      7865
#    macro avg       0.92      0.70      0.77      7865
# weighted avg       0.96      0.96      0.96      7865
#
#
#
# Evaluation for "food":
#                precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      7003
#            1       0.87      0.57      0.69       862
#
#     accuracy                           0.94      7865
#    macro avg       0.91      0.78      0.83      7865
# weighted avg       0.94      0.94      0.94      7865
#
#
#
# Evaluation for "shelter":
#                precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      7212
#            1       0.83      0.41      0.55       653
#
#     accuracy                           0.94      7865
#    macro avg       0.89      0.70      0.76      7865
# weighted avg       0.94      0.94      0.93      7865
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Evaluation for "clothing":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7757
#            1       0.91      0.09      0.17       108
#
#     accuracy                           0.99      7865
#    macro avg       0.95      0.55      0.58      7865
# weighted avg       0.99      0.99      0.98      7865
#
#
#
# Evaluation for "money":
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7692
#            1       0.67      0.02      0.04       173
#
#     accuracy                           0.98      7865
#    macro avg       0.82      0.51      0.52      7865
# weighted avg       0.97      0.98      0.97      7865
#
#
#
# Evaluation for "missing_people":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7785
#            1       1.00      0.01      0.02        80
#
#     accuracy                           0.99      7865
#    macro avg       0.99      0.51      0.51      7865
# weighted avg       0.99      0.99      0.99      7865
#
#
#
# Evaluation for "refugees":
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      7599
#            1       0.50      0.03      0.06       266
#
#     accuracy                           0.97      7865
#    macro avg       0.73      0.51      0.52      7865
# weighted avg       0.95      0.97      0.95      7865
#
#
#
# Evaluation for "death":
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7522
#            1       0.82      0.15      0.26       343
#
#     accuracy                           0.96      7865
#    macro avg       0.89      0.58      0.62      7865
# weighted avg       0.96      0.96      0.95      7865
#
#
#
# Evaluation for "other_aid":
#                precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      6837
#            1       0.67      0.04      0.07      1028
#
#     accuracy                           0.87      7865
#    macro avg       0.77      0.52      0.50      7865
# weighted avg       0.85      0.87      0.82      7865
#
#
#
# Evaluation for "infrastructure_related":
#                precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      7376
#            1       0.00      0.00      0.00       489
#
#     accuracy                           0.94      7865
#    macro avg       0.47      0.50      0.48      7865
# weighted avg       0.88      0.94      0.91      7865
#
#
#
# Evaluation for "transport":
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7489
#            1       0.73      0.09      0.17       376
#
#     accuracy                           0.95      7865
#    macro avg       0.84      0.55      0.57      7865
# weighted avg       0.95      0.95      0.94      7865
#
#
#
# Evaluation for "buildings":
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7484
#            1       0.76      0.14      0.24       381
#
#     accuracy                           0.96      7865
#    macro avg       0.86      0.57      0.61      7865
# weighted avg       0.95      0.96      0.94      7865
#
#
#
# Evaluation for "electricity":
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7713
#            1       0.83      0.03      0.06       152
#
#     accuracy                           0.98      7865
#    macro avg       0.91      0.52      0.53      7865
# weighted avg       0.98      0.98      0.97      7865
#
#
#
# Evaluation for "tools":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7822
#            1       0.00      0.00      0.00        43
#
#     accuracy                           0.99      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      0.99      0.99      7865
#
#
#
# Evaluation for "hospitals":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7771
#            1       0.00      0.00      0.00        94
#
#     accuracy                           0.99      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.98      0.99      0.98      7865
#
#
#
# Evaluation for "shops":
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7827
#            1       0.00      0.00      0.00        38
#
#     accuracy                           1.00      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      1.00      0.99      7865
#
#
#
# Evaluation for "aid_centers":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7783
#            1       0.00      0.00      0.00        82
#
#     accuracy                           0.99      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.98      0.99      0.98      7865
#
#
#
# Evaluation for "other_infrastructure":
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7549
#            1       0.00      0.00      0.00       316
#
#     accuracy                           0.96      7865
#    macro avg       0.48      0.50      0.49      7865
# weighted avg       0.92      0.96      0.94      7865
#
#
#
# Evaluation for "weather_related":
#                precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92      5695
#            1       0.84      0.72      0.77      2170
#
#     accuracy                           0.88      7865
#    macro avg       0.87      0.83      0.85      7865
# weighted avg       0.88      0.88      0.88      7865
#
#
#
# Evaluation for "floods":
#                precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      7246
#            1       0.87      0.49      0.63       619
#
#     accuracy                           0.95      7865
#    macro avg       0.91      0.74      0.80      7865
# weighted avg       0.95      0.95      0.95      7865
#
#
#
# Evaluation for "storm":
#                precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      7139
#            1       0.73      0.53      0.61       726
#
#     accuracy                           0.94      7865
#    macro avg       0.84      0.75      0.79      7865
# weighted avg       0.93      0.94      0.93      7865
#
#
#
# Evaluation for "fire":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7768
#            1       1.00      0.01      0.02        97
#
#     accuracy                           0.99      7865
#    macro avg       0.99      0.51      0.51      7865
# weighted avg       0.99      0.99      0.98      7865
#
#
#
# Evaluation for "earthquake":
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      7129
#            1       0.89      0.78      0.83       736
#
#     accuracy                           0.97      7865
#    macro avg       0.94      0.89      0.91      7865
# weighted avg       0.97      0.97      0.97      7865
#
#
#
# Evaluation for "cold":
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7707
#            1       0.74      0.09      0.16       158
#
#     accuracy                           0.98      7865
#    macro avg       0.86      0.54      0.57      7865
# weighted avg       0.98      0.98      0.97      7865
#
#
#
# Evaluation for "other_weather":
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7448
#            1       0.57      0.03      0.05       417
#
#     accuracy                           0.95      7865
#    macro avg       0.76      0.51      0.51      7865
# weighted avg       0.93      0.95      0.92      7865
#
#
#
# Evaluation for "direct_report":
#                precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92      6349
#            1       0.80      0.35      0.49      1516
#
#     accuracy                           0.86      7865
#    macro avg       0.83      0.67      0.70      7865
# weighted avg       0.85      0.86      0.83      7865

# %% [markdown]
# ### 8. Further improvement
# The RandomForest algorithm takes very long to fit the dataset so it is difficult to test many parameters with gridsearch. This is why I will try a support vector machine.

# %%
# build pipeline with count vecotrizer, tfidf and support vector machine
pipeline_SVC = Pipeline([
    ('vect', CountVectorizer(tokenizer = tokenize)),
    ('tfidf', TfidfTransformer()),
    ('multi-clf', MultiOutputClassifier(LinearSVC()))
])

# define parameters for gridsearch
parameters_SVC = {
    'vect__max_df': (.6, 1),
    'tfidf__norm': ('l1', 'l2'),
    'multi-clf__estimator__C': (.1, 1, 100)
}

# build parameter grid and fit data
cv_SVC = GridSearchCV(pipeline_SVC, parameters_SVC)
cv_SVC.fit(X_train, y_train.drop('child_alone', axis = 1))
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# GridSearchCV(estimator=Pipeline(steps=[('vect',
#                                         CountVectorizer(tokenizer=<function tokenize at 0x11c057ca0>)),
#                                        ('tfidf', TfidfTransformer()),
#                                        ('multi-clf',
#                                         MultiOutputClassifier(estimator=LinearSVC()))]),
#              param_grid={'multi-clf__estimator__C': (0.1, 1, 100),
#                          'tfidf__norm': ('l1', 'l2'),
#                          'vect__max_df': (0.6, 1)})

# %%
# run prediction with test data
y_pred = cv_SVC.predict(X_test)
y_test = y_test.drop('child_alone', axis = 1)

# print precision, recall and f1-score
i = 0
for col in y_test:
    print('Evaluation for "{}": \n {} \n\n'.format(col, classification_report(y_test[col], y_pred[:,i])))
    i += 1
# Out:
# Evaluation for "related":
#                precision    recall  f1-score   support
#
#            0       0.63      0.53      0.58      1862
#            1       0.86      0.91      0.88      5946
#            2       0.79      0.19      0.31        57
#
#     accuracy                           0.81      7865
#    macro avg       0.76      0.54      0.59      7865
# weighted avg       0.80      0.81      0.81      7865
#
#
#
# Evaluation for "request":
#                precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94      6555
#            1       0.75      0.60      0.67      1310
#
#     accuracy                           0.90      7865
#    macro avg       0.84      0.78      0.80      7865
# weighted avg       0.89      0.90      0.90      7865
#
#
#
# Evaluation for "offer":
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7838
#            1       0.00      0.00      0.00        27
#
#     accuracy                           1.00      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      1.00      0.99      7865
#
#
#
# Evaluation for "aid_related":
#                precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80      4650
#            1       0.72      0.68      0.70      3215
#
#     accuracy                           0.76      7865
#    macro avg       0.75      0.75      0.75      7865
# weighted avg       0.76      0.76      0.76      7865
#
#
#
# Evaluation for "medical_help":
#                precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96      7273
#            1       0.55      0.31      0.40       592
#
#     accuracy                           0.93      7865
#    macro avg       0.75      0.64      0.68      7865
# weighted avg       0.92      0.93      0.92      7865
#
#
#
# Evaluation for "medical_products":
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      7502
#            1       0.67      0.30      0.41       363
#
#     accuracy                           0.96      7865
#    macro avg       0.82      0.65      0.70      7865
# weighted avg       0.95      0.96      0.95      7865
#
#
#
# Evaluation for "search_and_rescue":
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7646
#            1       0.73      0.21      0.33       219
#
#     accuracy                           0.98      7865
#    macro avg       0.85      0.60      0.66      7865
# weighted avg       0.97      0.98      0.97      7865
#
#
#
# Evaluation for "security":
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7725
#            1       0.40      0.01      0.03       140
#
#     accuracy                           0.98      7865
#    macro avg       0.69      0.51      0.51      7865
# weighted avg       0.97      0.98      0.97      7865
#
#
#
# Evaluation for "military":
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      7621
#            1       0.63      0.32      0.43       244
#
#     accuracy                           0.97      7865
#    macro avg       0.81      0.66      0.71      7865
# weighted avg       0.97      0.97      0.97      7865
#
#
#
# Evaluation for "water":
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      7406
#            1       0.72      0.57      0.64       459
#
#     accuracy                           0.96      7865
#    macro avg       0.85      0.78      0.81      7865
# weighted avg       0.96      0.96      0.96      7865
#
#
#
# Evaluation for "food":
#                precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      7003
#            1       0.81      0.68      0.74       862
#
#     accuracy                           0.95      7865
#    macro avg       0.89      0.83      0.86      7865
# weighted avg       0.94      0.95      0.95      7865
#
#
#
# Evaluation for "shelter":
#                precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      7212
#            1       0.74      0.55      0.63       653
#
#     accuracy                           0.95      7865
#    macro avg       0.85      0.77      0.80      7865
# weighted avg       0.94      0.95      0.94      7865
#
#
#
# Evaluation for "clothing":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7757
#            1       0.82      0.46      0.59       108
#
#     accuracy                           0.99      7865
#    macro avg       0.91      0.73      0.79      7865
# weighted avg       0.99      0.99      0.99      7865
#
#
#
# Evaluation for "money":
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7692
#            1       0.56      0.27      0.36       173
#
#     accuracy                           0.98      7865
#    macro avg       0.77      0.63      0.68      7865
# weighted avg       0.97      0.98      0.98      7865
#
#
#
# Evaluation for "missing_people":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7785
#            1       0.54      0.09      0.15        80
#
#     accuracy                           0.99      7865
#    macro avg       0.76      0.54      0.57      7865
# weighted avg       0.99      0.99      0.99      7865
#
#
#
# Evaluation for "refugees":
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      7599
#            1       0.64      0.26      0.37       266
#
#     accuracy                           0.97      7865
#    macro avg       0.81      0.63      0.68      7865
# weighted avg       0.96      0.97      0.96      7865
#
#
#
# Evaluation for "death":
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      7522
#            1       0.73      0.47      0.57       343
#
#     accuracy                           0.97      7865
#    macro avg       0.85      0.73      0.78      7865
# weighted avg       0.97      0.97      0.97      7865
#
#
#
# Evaluation for "other_aid":
#                precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93      6837
#            1       0.48      0.19      0.28      1028
#
#     accuracy                           0.87      7865
#    macro avg       0.68      0.58      0.60      7865
# weighted avg       0.84      0.87      0.84      7865
#
#
#
# Evaluation for "infrastructure_related":
#                precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      7376
#            1       0.39      0.10      0.16       489
#
#     accuracy                           0.93      7865
#    macro avg       0.67      0.54      0.56      7865
# weighted avg       0.91      0.93      0.92      7865
#
#
#
# Evaluation for "transport":
#                precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      7489
#            1       0.63      0.21      0.31       376
#
#     accuracy                           0.96      7865
#    macro avg       0.80      0.60      0.65      7865
# weighted avg       0.95      0.96      0.95      7865
#
#
#
# Evaluation for "buildings":
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      7484
#            1       0.61      0.41      0.49       381
#
#     accuracy                           0.96      7865
#    macro avg       0.79      0.70      0.73      7865
# weighted avg       0.95      0.96      0.95      7865
#
#
#
# Evaluation for "electricity":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7713
#            1       0.65      0.26      0.37       152
#
#     accuracy                           0.98      7865
#    macro avg       0.82      0.63      0.68      7865
# weighted avg       0.98      0.98      0.98      7865
#
#
#
# Evaluation for "tools":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7822
#            1       0.00      0.00      0.00        43
#
#     accuracy                           0.99      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      0.99      0.99      7865
#
#
#
# Evaluation for "hospitals":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7771
#            1       0.62      0.05      0.10        94
#
#     accuracy                           0.99      7865
#    macro avg       0.81      0.53      0.55      7865
# weighted avg       0.98      0.99      0.98      7865
#
#
#
# Evaluation for "shops":
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7827
#            1       0.00      0.00      0.00        38
#
#     accuracy                           1.00      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      1.00      0.99      7865
#
#
#
# Evaluation for "aid_centers":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7783
#            1       0.67      0.05      0.09        82
#
#     accuracy                           0.99      7865
#    macro avg       0.83      0.52      0.54      7865
# weighted avg       0.99      0.99      0.99      7865
#
#
#
# Evaluation for "other_infrastructure":
#                precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      7549
#            1       0.22      0.04      0.07       316
#
#     accuracy                           0.96      7865
#    macro avg       0.59      0.52      0.53      7865
# weighted avg       0.93      0.96      0.94      7865
# Evaluation for "weather_related":
#                precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92      5695
#            1       0.81      0.72      0.76      2170
#
#     accuracy                           0.88      7865
#    macro avg       0.86      0.83      0.84      7865
# weighted avg       0.87      0.88      0.87      7865
#
#
#
# Evaluation for "floods":
#                precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      7246
#            1       0.85      0.54      0.66       619
#
#     accuracy                           0.96      7865
#    macro avg       0.91      0.77      0.82      7865
# weighted avg       0.95      0.96      0.95      7865
#
#
#
# Evaluation for "storm":
#                precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97      7139
#            1       0.69      0.59      0.64       726
#
#     accuracy                           0.94      7865
#    macro avg       0.82      0.78      0.80      7865
# weighted avg       0.93      0.94      0.94      7865
#
#
#
# Evaluation for "fire":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7768
#            1       0.85      0.24      0.37        97
#
#     accuracy                           0.99      7865
#    macro avg       0.92      0.62      0.68      7865
# weighted avg       0.99      0.99      0.99      7865
#
#
#
# Evaluation for "earthquake":
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      7129
#            1       0.88      0.75      0.81       736
#
#     accuracy                           0.97      7865
#    macro avg       0.93      0.87      0.90      7865
# weighted avg       0.97      0.97      0.97      7865
#
#
#
# Evaluation for "cold":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7707
#            1       0.67      0.37      0.48       158
#
#     accuracy                           0.98      7865
#    macro avg       0.83      0.68      0.74      7865
# weighted avg       0.98      0.98      0.98      7865
#
#
#
# Evaluation for "other_weather":
#                precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      7448
#            1       0.50      0.16      0.24       417
#
#     accuracy                           0.95      7865
#    macro avg       0.73      0.57      0.61      7865
# weighted avg       0.93      0.95      0.93      7865
#
#
#
# Evaluation for "direct_report":
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      6349
#            1       0.66      0.50      0.57      1516
#
#     accuracy                           0.86      7865
#    macro avg       0.78      0.72      0.74      7865
# weighted avg       0.84      0.86      0.85      7865

# %% [markdown]
# The support vector machine yields slightly better results and is faster, so I would prefer this algorithm.

# %% [markdown]
# ### 9. Export models as a pickle file

# %%
# save both models
pickle.dump(cv_RF, open('../webapp/models/ML_pipeline_RF.pkl', 'wb'))
pickle.dump(cv_SVC, open('../webapp/models/ML_pipeline_SVC.pkl', 'wb'))
