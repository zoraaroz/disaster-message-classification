# %% [markdown]
# # ML Pipeline Preparation
# ### 1. Import libraries and load data from database

# %%
# import libraries
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import re
import pickle

# nltk
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

#sklearn
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report
# Out:
# [nltk_data] Downloading package punkt to /Users/zora/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# load data from database
engine = create_engine('sqlite:///../webapp/data/DisasterResponse.db')
df = pd.read_sql_table('messages_categories', engine)

# create X and y dataframes for pipeline
X = df['message'] # predictors
y = df.drop(['id', 'message', 'original', 'genre'], axis = 1).astype('int64') # labels

# %% [markdown]
# ### 2. Write a tokenization function to process text data

# %%
def tokenize(text):
    text_norm = re.sub(r'[^a-zA-Z0-9]', ' ', text) # normalize: remove punctuation
    word_list = word_tokenize(text_norm) # tokenize 
    word_list_clean = [w for w in word_list if w not in stopwords.words('english')] # remove stopwords
    word_list_stemmed = [PorterStemmer().stem(w) for w in word_list_clean] # stemm words
    return word_list_stemmed

# %% [markdown]
# ### 3. Build a machine learning pipeline

# %%
# build a pipeline with countvectorizer, tfidf and random forest classifier
pipeline_RF = Pipeline([
    ('vect', CountVectorizer(tokenizer = tokenize)),
    ('tfidf', TfidfTransformer()),
    ('multi-clf', MultiOutputClassifier(RandomForestClassifier()))
])

# %% [markdown]
# ### 4. Train pipeline

# %%
# split dataset into train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# fit data
pipeline_RF.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x124008040>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('multi-clf',
#                  MultiOutputClassifier(estimator=RandomForestClassifier()))])

# %% [markdown]
# ### 5. Test model

# %%
# run prediction with test data
y_pred = pipeline_RF.predict(X_test)

# %%
# print precision, recall and f1-score
i = 0
for col in y_test:
    print('Evaluation for "{}": \n {} \n\n'.format(col, classification_report(y_test[col], y_pred[:,i])))
    i += 1
# Out:
# Evaluation for "related":
#                precision    recall  f1-score   support
#
#            0       0.70      0.41      0.52      1795
#            1       0.84      0.95      0.89      6021
#            2       0.50      0.49      0.49        49
#
#     accuracy                           0.82      7865
#    macro avg       0.68      0.62      0.63      7865
# weighted avg       0.81      0.82      0.80      7865
#
#
#
# Evaluation for "request":
#                precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      6490
#            1       0.84      0.49      0.62      1375
#
#     accuracy                           0.89      7865
#    macro avg       0.87      0.73      0.78      7865
# weighted avg       0.89      0.89      0.88      7865
#
#
#
# Evaluation for "offer":
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7833
#            1       0.00      0.00      0.00        32
#
#     accuracy                           1.00      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      1.00      0.99      7865
#
#
#
# Evaluation for "aid_related":
#                precision    recall  f1-score   support
#
#            0       0.79      0.84      0.82      4551
#            1       0.76      0.70      0.73      3314
#
#     accuracy                           0.78      7865
#    macro avg       0.78      0.77      0.77      7865
# weighted avg       0.78      0.78      0.78      7865
#
#
#
# Evaluation for "medical_help":
#                precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      7226
#            1       0.67      0.09      0.16       639
#
#     accuracy                           0.92      7865
#    macro avg       0.80      0.54      0.56      7865
# weighted avg       0.90      0.92      0.89      7865
#
#
#
# Evaluation for "medical_products":
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      7466
#            1       0.78      0.10      0.18       399
#
#     accuracy                           0.95      7865
#    macro avg       0.87      0.55      0.58      7865
# weighted avg       0.95      0.95      0.94      7865
#
#
#
# Evaluation for "search_and_rescue":
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      7624
#            1       0.92      0.05      0.09       241
#
#     accuracy                           0.97      7865
#    macro avg       0.95      0.52      0.54      7865
# weighted avg       0.97      0.97      0.96      7865
#
#
#
# Evaluation for "security":
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7718
#            1       0.00      0.00      0.00       147
#
#     accuracy                           0.98      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.96      0.98      0.97      7865
#
#
#
# Evaluation for "military":
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      7613
#            1       0.80      0.08      0.14       252
#
#     accuracy                           0.97      7865
#    macro avg       0.89      0.54      0.56      7865
# weighted avg       0.96      0.97      0.96      7865
#
#
#
# Evaluation for "child_alone":
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7865
#
#     accuracy                           1.00      7865
#    macro avg       1.00      1.00      1.00      7865
# weighted avg       1.00      1.00      1.00      7865
#
#
#
# Evaluation for "water":
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7355
#            1       0.89      0.39      0.54       510
#
#     accuracy                           0.96      7865
#    macro avg       0.92      0.69      0.76      7865
# weighted avg       0.95      0.96      0.95      7865
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Evaluation for "food":
#                precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      6959
#            1       0.84      0.61      0.71       906
#
#     accuracy                           0.94      7865
#    macro avg       0.90      0.80      0.84      7865
# weighted avg       0.94      0.94      0.94      7865
#
#
#
# Evaluation for "shelter":
#                precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      7141
#            1       0.85      0.36      0.50       724
#
#     accuracy                           0.94      7865
#    macro avg       0.89      0.68      0.73      7865
# weighted avg       0.93      0.94      0.92      7865
#
#
#
# Evaluation for "clothing":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7739
#            1       0.75      0.17      0.27       126
#
#     accuracy                           0.99      7865
#    macro avg       0.87      0.58      0.63      7865
# weighted avg       0.98      0.99      0.98      7865
#
#
#
# Evaluation for "money":
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7672
#            1       1.00      0.04      0.07       193
#
#     accuracy                           0.98      7865
#    macro avg       0.99      0.52      0.53      7865
# weighted avg       0.98      0.98      0.97      7865
#
#
#
# Evaluation for "missing_people":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7779
#            1       0.67      0.02      0.04        86
#
#     accuracy                           0.99      7865
#    macro avg       0.83      0.51      0.52      7865
# weighted avg       0.99      0.99      0.98      7865
#
#
#
# Evaluation for "refugees":
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      7602
#            1       0.62      0.04      0.07       263
#
#     accuracy                           0.97      7865
#    macro avg       0.80      0.52      0.53      7865
# weighted avg       0.96      0.97      0.95      7865
#
#
#
# Evaluation for "death":
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7487
#            1       0.79      0.10      0.17       378
#
#     accuracy                           0.96      7865
#    macro avg       0.87      0.55      0.58      7865
# weighted avg       0.95      0.96      0.94      7865
#
#
#
# Evaluation for "other_aid":
#                precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93      6887
#            1       0.66      0.04      0.08       978
#
#     accuracy                           0.88      7865
#    macro avg       0.77      0.52      0.51      7865
# weighted avg       0.85      0.88      0.83      7865
#
#
#
# Evaluation for "infrastructure_related":
#                precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      7334
#            1       0.20      0.00      0.00       531
#
#     accuracy                           0.93      7865
#    macro avg       0.57      0.50      0.48      7865
# weighted avg       0.88      0.93      0.90      7865
#
#
#
# Evaluation for "transport":
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      7494
#            1       0.74      0.05      0.09       371
#
#     accuracy                           0.95      7865
#    macro avg       0.85      0.52      0.53      7865
# weighted avg       0.94      0.95      0.93      7865
#
#
#
# Evaluation for "buildings":
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7448
#            1       0.72      0.13      0.22       417
#
#     accuracy                           0.95      7865
#    macro avg       0.84      0.56      0.60      7865
# weighted avg       0.94      0.95      0.94      7865
#
#
#
# Evaluation for "electricity":
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7715
#            1       1.00      0.02      0.04       150
#
#     accuracy                           0.98      7865
#    macro avg       0.99      0.51      0.51      7865
# weighted avg       0.98      0.98      0.97      7865
#
#
#
# Evaluation for "tools":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7818
#            1       0.00      0.00      0.00        47
#
#     accuracy                           0.99      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      0.99      0.99      7865
#
#
#
# Evaluation for "hospitals":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7789
#            1       0.00      0.00      0.00        76
#
#     accuracy                           0.99      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.98      0.99      0.99      7865
#
#
#
# Evaluation for "shops":
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7829
#            1       0.00      0.00      0.00        36
#
#     accuracy                           1.00      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      1.00      0.99      7865
#
#
#
# Evaluation for "aid_centers":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7773
#            1       0.00      0.00      0.00        92
#
#     accuracy                           0.99      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.98      0.99      0.98      7865
#
#
#
# Evaluation for "other_infrastructure":
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      7491
#            1       0.33      0.00      0.01       374
#
#     accuracy                           0.95      7865
#    macro avg       0.64      0.50      0.49      7865
# weighted avg       0.92      0.95      0.93      7865
#
#
#
# Evaluation for "weather_related":
#                precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92      5684
#            1       0.85      0.71      0.77      2181
#
#     accuracy                           0.88      7865
#    macro avg       0.87      0.83      0.85      7865
# weighted avg       0.88      0.88      0.88      7865
#
#
#
# Evaluation for "floods":
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7198
#            1       0.93      0.52      0.67       667
#
#     accuracy                           0.96      7865
#    macro avg       0.94      0.76      0.82      7865
# weighted avg       0.95      0.96      0.95      7865
#
#
#
# Evaluation for "storm":
#                precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      7150
#            1       0.78      0.52      0.63       715
#
#     accuracy                           0.94      7865
#    macro avg       0.87      0.75      0.80      7865
# weighted avg       0.94      0.94      0.94      7865
#
#
#
# Evaluation for "fire":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7777
#            1       0.00      0.00      0.00        88
#
#     accuracy                           0.99      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.98      0.99      0.98      7865
#
#
#
# Evaluation for "earthquake":
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      7156
#            1       0.89      0.78      0.83       709
#
#     accuracy                           0.97      7865
#    macro avg       0.93      0.89      0.91      7865
# weighted avg       0.97      0.97      0.97      7865
#
#
#
# Evaluation for "cold":
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7683
#            1       0.90      0.05      0.09       182
#
#     accuracy                           0.98      7865
#    macro avg       0.94      0.52      0.54      7865
# weighted avg       0.98      0.98      0.97      7865
#
#
#
# Evaluation for "other_weather":
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7464
#            1       0.57      0.03      0.06       401
#
#     accuracy                           0.95      7865
#    macro avg       0.76      0.51      0.52      7865
# weighted avg       0.93      0.95      0.93      7865
#
#
#
# Evaluation for "direct_report":
#                precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92      6297
#            1       0.80      0.37      0.50      1568
#
#     accuracy                           0.86      7865
#    macro avg       0.83      0.67      0.71      7865
# weighted avg       0.85      0.86      0.83      7865

# %% [markdown]
# ### 6. Improve model

# %%
# define parameters for gridsearch
parameters_RF = {
    'vect__max_df': (.6, 1),
    'tfidf__norm': ('l1', 'l2'),
    'multi-clf__estimator__criterion': ('gini', 'entropy')
}

# build parameter grid and fit data
cv_RF = GridSearchCV(pipeline_RF, parameters_RF)
cv_RF.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('vect',
#                                         CountVectorizer(tokenizer=<function tokenize at 0x124008040>)),
#                                        ('tfidf', TfidfTransformer()),
#                                        ('multi-clf',
#                                         MultiOutputClassifier(estimator=RandomForestClassifier()))]),
#              param_grid={'multi-clf__estimator__criterion': ('gini',
#                                                              'entropy')})

# %% [markdown]
# ### 7. Test tuned model

# %%
# run prediction with test data
y_pred = cv_RF.predict(X_test)

# print precision, recall and f1-score
i = 0
for col in y_test:
    print('Evaluation for "{}": \n {} \n\n'.format(col, classification_report(y_test[col], y_pred[:,i])))
    i += 1
# Out:
# Evaluation for "related":
#                precision    recall  f1-score   support
#
#            0       0.72      0.40      0.52      1795
#            1       0.84      0.95      0.89      6021
#            2       0.58      0.39      0.46        49
#
#     accuracy                           0.82      7865
#    macro avg       0.71      0.58      0.62      7865
# weighted avg       0.81      0.82      0.80      7865
#
#
#
# Evaluation for "request":
#                precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      6490
#            1       0.84      0.49      0.62      1375
#
#     accuracy                           0.89      7865
#    macro avg       0.87      0.74      0.78      7865
# weighted avg       0.89      0.89      0.88      7865
#
#
#
# Evaluation for "offer":
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7833
#            1       0.00      0.00      0.00        32
#
#     accuracy                           1.00      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      1.00      0.99      7865
#
#
#
# Evaluation for "aid_related":
#                precision    recall  f1-score   support
#
#            0       0.79      0.84      0.81      4551
#            1       0.76      0.70      0.73      3314
#
#     accuracy                           0.78      7865
#    macro avg       0.77      0.77      0.77      7865
# weighted avg       0.78      0.78      0.78      7865
#
#
#
# Evaluation for "medical_help":
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      7226
#            1       0.70      0.07      0.13       639
#
#     accuracy                           0.92      7865
#    macro avg       0.81      0.53      0.54      7865
# weighted avg       0.91      0.92      0.89      7865
#
#
#
# Evaluation for "medical_products":
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      7466
#            1       0.71      0.07      0.13       399
#
#     accuracy                           0.95      7865
#    macro avg       0.83      0.54      0.55      7865
# weighted avg       0.94      0.95      0.93      7865
#
#
#
# Evaluation for "search_and_rescue":
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      7624
#            1       0.82      0.04      0.07       241
#
#     accuracy                           0.97      7865
#    macro avg       0.89      0.52      0.53      7865
# weighted avg       0.97      0.97      0.96      7865
#
#
#
# Evaluation for "security":
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7718
#            1       0.00      0.00      0.00       147
#
#     accuracy                           0.98      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.96      0.98      0.97      7865
#
#
#
# Evaluation for "military":
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      7613
#            1       0.70      0.06      0.10       252
#
#     accuracy                           0.97      7865
#    macro avg       0.83      0.53      0.54      7865
# weighted avg       0.96      0.97      0.96      7865
#
#
#
# Evaluation for "child_alone":
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7865
#
#     accuracy                           1.00      7865
#    macro avg       1.00      1.00      1.00      7865
# weighted avg       1.00      1.00      1.00      7865
#
#
#
# Evaluation for "water":
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7355
#            1       0.87      0.36      0.51       510
#
#     accuracy                           0.95      7865
#    macro avg       0.91      0.68      0.74      7865
# weighted avg       0.95      0.95      0.95      7865
#
#
#
# Evaluation for "food":
#                precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      6959
#            1       0.85      0.56      0.67       906
#
#     accuracy                           0.94      7865
#    macro avg       0.90      0.77      0.82      7865
# weighted avg       0.93      0.94      0.93      7865
#
#
#
# Evaluation for "shelter":
#                precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      7141
#            1       0.84      0.36      0.51       724
#
#     accuracy                           0.94      7865
#    macro avg       0.89      0.68      0.74      7865
# weighted avg       0.93      0.94      0.92      7865
#
#
#
# Evaluation for "clothing":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7739
#            1       0.79      0.18      0.30       126
#
#     accuracy                           0.99      7865
#    macro avg       0.89      0.59      0.64      7865
# weighted avg       0.98      0.99      0.98      7865
#
#
#
# Evaluation for "money":
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7672
#            1       1.00      0.03      0.05       193
#
#     accuracy                           0.98      7865
#    macro avg       0.99      0.51      0.52      7865
# weighted avg       0.98      0.98      0.96      7865
#
#
#
# Evaluation for "missing_people":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7779
#            1       0.67      0.02      0.04        86
#
#     accuracy                           0.99      7865
#    macro avg       0.83      0.51      0.52      7865
# weighted avg       0.99      0.99      0.98      7865
#
#
#
# Evaluation for "refugees":
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      7602
#            1       0.55      0.04      0.08       263
#
#     accuracy                           0.97      7865
#    macro avg       0.76      0.52      0.53      7865
# weighted avg       0.95      0.97      0.95      7865
#
#
#
# Evaluation for "death":
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7487
#            1       0.79      0.13      0.22       378
#
#     accuracy                           0.96      7865
#    macro avg       0.87      0.56      0.60      7865
# weighted avg       0.95      0.96      0.94      7865
#
#
#
# Evaluation for "other_aid":
#                precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93      6887
#            1       0.60      0.03      0.07       978
#
#     accuracy                           0.88      7865
#    macro avg       0.74      0.52      0.50      7865
# weighted avg       0.84      0.88      0.83      7865
#
#
#
# Evaluation for "infrastructure_related":
#                precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      7334
#            1       0.25      0.00      0.00       531
#
#     accuracy                           0.93      7865
#    macro avg       0.59      0.50      0.48      7865
# weighted avg       0.89      0.93      0.90      7865
#
#
#
# Evaluation for "transport":
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      7494
#            1       0.74      0.05      0.09       371
#
#     accuracy                           0.95      7865
#    macro avg       0.85      0.52      0.53      7865
# weighted avg       0.94      0.95      0.93      7865
#
#
#
# Evaluation for "buildings":
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7448
#            1       0.69      0.13      0.22       417
#
#     accuracy                           0.95      7865
#    macro avg       0.82      0.56      0.60      7865
# weighted avg       0.94      0.95      0.93      7865
#
#
#
# Evaluation for "electricity":
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7715
#            1       1.00      0.02      0.04       150
#
#     accuracy                           0.98      7865
#    macro avg       0.99      0.51      0.51      7865
# weighted avg       0.98      0.98      0.97      7865
#
#
#
# Evaluation for "tools":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7818
#            1       0.00      0.00      0.00        47
#
#     accuracy                           0.99      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      0.99      0.99      7865
#
#
#
# Evaluation for "hospitals":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7789
#            1       0.00      0.00      0.00        76
#
#     accuracy                           0.99      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.98      0.99      0.99      7865
# Evaluation for "shops":
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7829
#            1       0.00      0.00      0.00        36
#
#     accuracy                           1.00      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      1.00      0.99      7865
#
#
#
# Evaluation for "aid_centers":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7773
#            1       0.00      0.00      0.00        92
#
#     accuracy                           0.99      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.98      0.99      0.98      7865
#
#
#
# Evaluation for "other_infrastructure":
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      7491
#            1       0.00      0.00      0.00       374
#
#     accuracy                           0.95      7865
#    macro avg       0.48      0.50      0.49      7865
# weighted avg       0.91      0.95      0.93      7865
#
#
#
# Evaluation for "weather_related":
#                precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92      5684
#            1       0.85      0.70      0.77      2181
#
#     accuracy                           0.88      7865
#    macro avg       0.87      0.83      0.85      7865
# weighted avg       0.88      0.88      0.88      7865
#
#
#
# Evaluation for "floods":
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      7198
#            1       0.93      0.49      0.64       667
#
#     accuracy                           0.95      7865
#    macro avg       0.94      0.74      0.81      7865
# weighted avg       0.95      0.95      0.95      7865
#
#
#
# Evaluation for "storm":
#                precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      7150
#            1       0.78      0.49      0.60       715
#
#     accuracy                           0.94      7865
#    macro avg       0.86      0.74      0.78      7865
# weighted avg       0.94      0.94      0.93      7865
#
#
#
# Evaluation for "fire":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7777
#            1       0.00      0.00      0.00        88
#
#     accuracy                           0.99      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.98      0.99      0.98      7865
#
#
#
# Evaluation for "earthquake":
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      7156
#            1       0.88      0.78      0.83       709
#
#     accuracy                           0.97      7865
#    macro avg       0.93      0.88      0.91      7865
# weighted avg       0.97      0.97      0.97      7865
#
#
#
# Evaluation for "cold":
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7683
#            1       1.00      0.07      0.12       182
#
#     accuracy                           0.98      7865
#    macro avg       0.99      0.53      0.56      7865
# weighted avg       0.98      0.98      0.97      7865
#
#
#
# Evaluation for "other_weather":
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7464
#            1       0.67      0.02      0.05       401
#
#     accuracy                           0.95      7865
#    macro avg       0.81      0.51      0.51      7865
# weighted avg       0.94      0.95      0.93      7865
#
#
#
# Evaluation for "direct_report":
#                precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92      6297
#            1       0.81      0.36      0.50      1568
#
#     accuracy                           0.86      7865
#    macro avg       0.83      0.67      0.71      7865
# weighted avg       0.85      0.86      0.83      7865

# %% [markdown]
# ### 8. Further improvement
# The RandomForest algorithm takes very long to fit the dataset so it is difficult to test many parameters with gridsearch. This is why I will try a support vector machine.

# %%
# build pipeline with count vecotrizer, tfidf and support vector machine
pipeline_SVC = Pipeline([
    ('vect', CountVectorizer(tokenizer = tokenize)),
    ('tfidf', TfidfTransformer()),
    ('multi-clf', MultiOutputClassifier(LinearSVC()))
])

# define parameters for gridsearch
parameters_SVC = {
    'vect__max_df': (.6, 1),
    'tfidf__norm': ('l1', 'l2'),
    'multi-clf__estimator__C': (.1, 1, 100)
}

# build parameter grid and fit data
cv_SVC = GridSearchCV(pipeline_SVC, parameters_SVC)
cv_SVC.fit(X_train, y_train.drop('child_alone', axis = 1))
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# GridSearchCV(estimator=Pipeline(steps=[('vect',
#                                         CountVectorizer(tokenizer=<function tokenize at 0x124008040>)),
#                                        ('tfidf', TfidfTransformer()),
#                                        ('multi-clf',
#                                         MultiOutputClassifier(estimator=LinearSVC()))]),
#              param_grid={'multi-clf__estimator__C': (0.1, 1, 100),
#                          'vect__max_df': (0.6, 1)})

# %%
# run prediction with test data
y_pred = cv_SVC.predict(X_test)

# print precision, recall and f1-score
i = 0
for col in y_test:
    print('Evaluation for "{}": \n {} \n\n'.format(col, classification_report(y_test[col], y_pred[:,i])))
    i += 1
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Evaluation for "related":
#                precision    recall  f1-score   support
#
#            0       0.71      0.40      0.51      1795
#            1       0.84      0.95      0.89      6021
#            2       0.00      0.00      0.00        49
#
#     accuracy                           0.82      7865
#    macro avg       0.52      0.45      0.47      7865
# weighted avg       0.80      0.82      0.80      7865
#
#
#
# Evaluation for "request":
#                precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94      6490
#            1       0.82      0.56      0.66      1375
#
#     accuracy                           0.90      7865
#    macro avg       0.87      0.77      0.80      7865
# weighted avg       0.90      0.90      0.89      7865
#
#
#
# Evaluation for "offer":
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7833
#            1       0.00      0.00      0.00        32
#
#     accuracy                           1.00      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      1.00      0.99      7865
#
#
#
# Evaluation for "aid_related":
#                precision    recall  f1-score   support
#
#            0       0.78      0.87      0.82      4551
#            1       0.78      0.67      0.72      3314
#
#     accuracy                           0.78      7865
#    macro avg       0.78      0.77      0.77      7865
# weighted avg       0.78      0.78      0.78      7865
#
#
#
# Evaluation for "medical_help":
#                precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96      7226
#            1       0.65      0.17      0.27       639
#
#     accuracy                           0.93      7865
#    macro avg       0.79      0.58      0.61      7865
# weighted avg       0.91      0.93      0.90      7865
#
#
#
# Evaluation for "medical_products":
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7466
#            1       0.74      0.14      0.24       399
#
#     accuracy                           0.95      7865
#    macro avg       0.85      0.57      0.61      7865
# weighted avg       0.95      0.95      0.94      7865
#
#
#
# Evaluation for "search_and_rescue":
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      7624
#            1       1.00      0.06      0.11       241
#
#     accuracy                           0.97      7865
#    macro avg       0.99      0.53      0.55      7865
# weighted avg       0.97      0.97      0.96      7865
#
#
#
# Evaluation for "security":
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7718
#            1       0.00      0.00      0.00       147
#
#     accuracy                           0.98      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.96      0.98      0.97      7865
#
#
#
# Evaluation for "military":
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      7613
#            1       0.61      0.14      0.23       252
#
#     accuracy                           0.97      7865
#    macro avg       0.79      0.57      0.61      7865
# weighted avg       0.96      0.97      0.96      7865
#
#
#
# Evaluation for "child_alone":
#                precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98      7865
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.96      7865
#    macro avg       0.50      0.48      0.49      7865
# weighted avg       1.00      0.96      0.98      7865
#
#
#
# Evaluation for "water":
#                precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95      7355
#            1       0.29      0.37      0.33       510
#
#     accuracy                           0.90      7865
#    macro avg       0.62      0.65      0.64      7865
# weighted avg       0.91      0.90      0.91      7865
#
#
#
# Evaluation for "food":
#                precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93      6959
#            1       0.31      0.15      0.20       906
#
#     accuracy                           0.86      7865
#    macro avg       0.60      0.55      0.56      7865
# weighted avg       0.83      0.86      0.84      7865
#
#
#
# Evaluation for "shelter":
#                precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      7141
#            1       0.21      0.02      0.03       724
#
#     accuracy                           0.90      7865
#    macro avg       0.56      0.51      0.49      7865
# weighted avg       0.84      0.90      0.86      7865
#
#
#
# Evaluation for "clothing":
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7739
#            1       0.00      0.00      0.00       126
#
#     accuracy                           0.98      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.97      0.98      0.98      7865
#
#
#
# Evaluation for "money":
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7672
#            1       0.00      0.00      0.00       193
#
#     accuracy                           0.98      7865
#    macro avg       0.49      0.50      0.49      7865
# weighted avg       0.95      0.98      0.96      7865
#
#
#
# Evaluation for "missing_people":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7779
#            1       0.00      0.00      0.00        86
#
#     accuracy                           0.98      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.98      0.98      0.98      7865
#
#
#
# Evaluation for "refugees":
#                precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      7602
#            1       0.07      0.03      0.05       263
#
#     accuracy                           0.95      7865
#    macro avg       0.52      0.51      0.51      7865
# weighted avg       0.94      0.95      0.94      7865
#
#
#
# Evaluation for "death":
#                precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      7487
#            1       0.03      0.01      0.02       378
#
#     accuracy                           0.93      7865
#    macro avg       0.49      0.50      0.49      7865
# weighted avg       0.91      0.93      0.92      7865
#
#
#
# Evaluation for "other_aid":
#                precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93      6887
#            1       0.22      0.00      0.00       978
#
#     accuracy                           0.88      7865
#    macro avg       0.55      0.50      0.47      7865
# weighted avg       0.79      0.88      0.82      7865
#
#
#
# Evaluation for "infrastructure_related":
#                precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96      7334
#            1       0.17      0.02      0.03       531
#
#     accuracy                           0.93      7865
#    macro avg       0.55      0.50      0.50      7865
# weighted avg       0.88      0.93      0.90      7865
#
#
#
# Evaluation for "transport":
#                precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      7494
#            1       0.12      0.04      0.06       371
#
#     accuracy                           0.94      7865
#    macro avg       0.54      0.51      0.52      7865
# weighted avg       0.91      0.94      0.93      7865
#
#
#
# Evaluation for "buildings":
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7448
#            1       0.00      0.00      0.00       417
#
#     accuracy                           0.94      7865
#    macro avg       0.47      0.50      0.49      7865
# weighted avg       0.90      0.94      0.92      7865
#
#
#
# Evaluation for "electricity":
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7715
#            1       0.00      0.00      0.00       150
#
#     accuracy                           0.98      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.96      0.98      0.97      7865
#
#
#
# Evaluation for "tools":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7818
#            1       0.00      0.00      0.00        47
#
#     accuracy                           0.99      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      0.99      0.99      7865
#
#
#
# Evaluation for "hospitals":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7789
#            1       0.00      0.00      0.00        76
#
#     accuracy                           0.99      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.98      0.99      0.99      7865
#
#
#
# Evaluation for "shops":
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7829
#            1       0.00      0.00      0.00        36
#
#     accuracy                           1.00      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      1.00      0.99      7865
#
#
#
# Evaluation for "aid_centers":
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7773
#            1       0.00      0.00      0.00        92
#
#     accuracy                           0.99      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.98      0.99      0.98      7865
#
#
#
# Evaluation for "other_infrastructure":
#                precision    recall  f1-score   support
#
#            0       0.97      0.80      0.88      7491
#            1       0.11      0.48      0.18       374
#
#     accuracy                           0.79      7865
#    macro avg       0.54      0.64      0.53      7865
# weighted avg       0.93      0.79      0.85      7865
#
#
#
# Evaluation for "weather_related":
#                precision    recall  f1-score   support
#
#            0       0.76      1.00      0.86      5684
#            1       0.94      0.16      0.27      2181
#
#     accuracy                           0.76      7865
#    macro avg       0.85      0.58      0.57      7865
# weighted avg       0.81      0.76      0.70      7865
#
#
#
# Evaluation for "floods":
#                precision    recall  f1-score   support
#
#            0       0.92      0.95      0.94      7198
#            1       0.24      0.16      0.19       667
#
#     accuracy                           0.88      7865
#    macro avg       0.58      0.56      0.56      7865
# weighted avg       0.87      0.88      0.87      7865
#
#
#
# Evaluation for "storm":
#                precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      7150
#            1       0.00      0.00      0.00       715
#
#     accuracy                           0.91      7865
#    macro avg       0.45      0.50      0.48      7865
# weighted avg       0.83      0.91      0.87      7865
#
#
#
# Evaluation for "fire":
#                precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96      7777
#            1       0.01      0.08      0.02        88
#
#     accuracy                           0.92      7865
#    macro avg       0.50      0.51      0.49      7865
# weighted avg       0.98      0.92      0.95      7865
#
#
#
# Evaluation for "earthquake":
#                precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      7156
#            1       0.08      0.00      0.01       709
#
#     accuracy                           0.91      7865
#    macro avg       0.49      0.50      0.48      7865
# weighted avg       0.84      0.91      0.87      7865
#
#
#
# Evaluation for "cold":
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7683
#            1       0.22      0.03      0.05       182
#
#     accuracy                           0.98      7865
#    macro avg       0.60      0.51      0.52      7865
# weighted avg       0.96      0.98      0.97      7865
#
#
#
# Evaluation for "other_weather":
#                precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91      7464
#            1       0.05      0.11      0.07       401
#
#     accuracy                           0.84      7865
#    macro avg       0.50      0.50      0.49      7865
# weighted avg       0.90      0.84      0.87      7865
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-41-128f5707a8c3> in <module>
#       3 i = 0
#       4 for col in y_test:
# ----> 5     print('Evaluation for "{}": \n {} \n\n'.format(col, classification_report(y_test[col], y_pred[:,i])))
#       6     i += 1
#
# IndexError: index 35 is out of bounds for axis 1 with size 35

# %% [markdown]
# The support vector machine yields slightly better results and is faster, so I would prefer this algorithm.

# %% [markdown]
# ### 9. Export models as a pickle file

# %%
# save both models
pickle.dump(cv_RF, open('../webapp/models/ML_pipeline_RF.sav', 'wb'))
pickle.dump(cv_SVC, open('../webapp/models/ML_pipeline_SVC.sav', 'wb'))
